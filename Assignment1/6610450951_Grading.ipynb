# %% [markdown]
# ## 6610450951 Tontawan Janthai

# %% [markdown]
# ## Read data

# %%
import pandas as pd
df = pd.read_excel("Psycology.xls")
df.head()
# Out:
#       เพศ  อายุ เคยมีแฟนมาแล้ว  (คน) จำนวนครั้งที่ไปออกกำลังกายต่อสัปดาห์  \
# 0    Male    28                    5                                    3
# 1    Male    23                    5                                    2
# 2  Female    23                    1                                    3
# 3  Female    20                    5                                    5
# 4    Male    29                    4                                    3
#
#        ระยะเวลาการนอน นิสิยการกินอาหาร เคยคิดฆ่าตัวตาย  \
# 0         5-6 ชั่วโมง      อาหารสุขภาพ             Yes
# 1   มากกว่า 8 ชั่วโมง      อาหารทั่วไป              No
# 2  น้อยกว่า 5 ชั่วโมง      อาหารสุขภาพ             Yes
# 3   มากกว่า 8 ชั่วโมง         Junkfood             Yes
# 4   มากกว่า 8 ชั่วโมง         Junkfood             Yes
#
#   จำนวนชั่วโมงที่เข้าห้องสมุดในหนึ่งสัปดาห์ ระดับความเครียดด้านการเงิน  \
# 0                                         8                          3
# 1                                        10                          4
# 2                                         0                          3
# 3                                         2                          5
# 4                                         1                          3
#
#   เคยกินยานอนหลับ ภาวะซึมเศร้า
# 0             Yes          Yes
# 1              No          Yes
# 2              No           No
# 3              No          Yes
# 4              No          Yes

# %%
df.columns
# Out:
# Index(['เพศ', 'อายุ', 'เคยมีแฟนมาแล้ว  (คน)',
#        'จำนวนครั้งที่ไปออกกำลังกายต่อสัปดาห์', 'ระยะเวลาการนอน',
#        'นิสิยการกินอาหาร', 'เคยคิดฆ่าตัวตาย',
#        'จำนวนชั่วโมงที่เข้าห้องสมุดในหนึ่งสัปดาห์',
#        'ระดับความเครียดด้านการเงิน', 'เคยกินยานอนหลับ', 'ภาวะซึมเศร้า'],
#       dtype='object')

# %% [markdown]
# ### See if there is any suspicious values

# %%
genders = df['เพศ'].unique()
ages = df['อายุ'].unique()
girlfriend_amount = df['เคยมีแฟนมาแล้ว  (คน)'].unique()
exercise = df['จำนวนครั้งที่ไปออกกำลังกายต่อสัปดาห์'].unique()
sleep_time = df['ระยะเวลาการนอน'].unique()
food_habit = df['นิสิยการกินอาหาร'].unique()
sucide = df['เคยคิดฆ่าตัวตาย'].unique()
library_time = df['จำนวนชั่วโมงที่เข้าห้องสมุดในหนึ่งสัปดาห์'].unique()
money_status = df['ระดับความเครียดด้านการเงิน'].unique()
sleeping_pill = df['เคยกินยานอนหลับ'].unique()
is_sadness = df['ภาวะซึมเศร้า'].unique()

print('เพศ ', genders)
print('อายุ ', ages)
print('เคยมีแฟนมาแล้ว  (คน) ', girlfriend_amount)
print('จำนวนครั้งที่ไปออกกำลังกายต่อสัปดาห์ ', exercise)
print('ระยะเวลาการนอน', sleep_time)
print('นิสิยการกินอาหาร ', food_habit)
print('เคยคิดฆ่าตัวตาย ', sucide)
print('จำนวนชั่วโมงที่เข้าห้องสมุดในหนึ่งสัปดาห์ ', library_time)
print('ระดับความเครียดด้านการเงิน ', money_status)
print('เคยกินยานอนหลับ ', sleeping_pill)
print('ภาวะซึมเศร้า', is_sadness)
# Out:
# เพศ  ['Male' 'Female']
# อายุ  [28 23 20 29 31 24 33 25 19 34 21 30 32 26 22 27 18]
# เคยมีแฟนมาแล้ว  (คน)  [5 1 4 2 3 '?']
# จำนวนครั้งที่ไปออกกำลังกายต่อสัปดาห์  [3 2 5 4 '?' 1]
# ระยะเวลาการนอน ['5-6 ชั่วโมง' 'มากกว่า 8 ชั่วโมง' 'น้อยกว่า 5 ชั่วโมง' '7-8 ชั่วโมง']
# นิสิยการกินอาหาร  ['อาหารสุขภาพ' 'อาหารทั่วไป' 'Junkfood']
# เคยคิดฆ่าตัวตาย  ['Yes' 'No']
# จำนวนชั่วโมงที่เข้าห้องสมุดในหนึ่งสัปดาห์  [8 10 0 2 1 3 11 12 9 7 4 6 '?' 5]
# ระดับความเครียดด้านการเงิน  [3 4 5 '?' 1 2]
# เคยกินยานอนหลับ  ['Yes' 'No']
# ภาวะซึมเศร้า ['Yes' 'No']

# %% [markdown]
# ### Ignore all rows that has '?' in it

# %%
#Before
print(f"Data size before cut is {df.shape[0]}")

#cut
df = df[~df.isin(['?']).any(axis=1)]

#After
print(f"Data size after cut is {df.shape[0]}")
# Out:
# Data size before cut is 502
# Data size after cut is 467

# %% [markdown]
# ### Data Mapping

# %%
df['เพศ'] = df['เพศ'].replace({'Male': 1, 'Female': 0})

#'อายุ' is no need for mapping
#'เคยมีแฟนมาแล้ว  (คน)' is no need for mapping
#'จำนวนครั้งที่ไปออกกำลังกายต่อสัปดาห์' is no need for mapping

df['ระยะเวลาการนอน'] = df['ระยะเวลาการนอน'].replace({
    '5-6 ชั่วโมง': 5.5,
    'มากกว่า 8 ชั่วโมง': 8.5,
    'น้อยกว่า 5 ชั่วโมง': 4.5,
    '7-8 ชั่วโมง': 7.5
})

df['นิสิยการกินอาหาร'] = df['นิสิยการกินอาหาร'].replace({
    'อาหารสุขภาพ': 0, 
    'อาหารทั่วไป': 1, 
    'Junkfood': 2
})

df['เคยคิดฆ่าตัวตาย'] = df['เคยคิดฆ่าตัวตาย'].replace({'Yes': 1, 'No': 0})

#'จำนวนชั่วโมงที่เข้าห้องสมุดในหนึ่งสัปดาห์' is no need for mapping
#'ระดับความเครียดด้านการเงิน' is no need for mapping

df['เคยกินยานอนหลับ'] = df['เคยกินยานอนหลับ'].replace({'Yes': 1, 'No': 0})
df['ภาวะซึมเศร้า'] = df['ภาวะซึมเศร้า'].replace({'Yes': 1, 'No': 0})

df.head()
# Out:
# C:\Users\spire\AppData\Local\Temp\ipykernel_72868\2237283390.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['เพศ'] = df['เพศ'].replace({'Male': 1, 'Female': 0})
# C:\Users\spire\AppData\Local\Temp\ipykernel_72868\2237283390.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['ระยะเวลาการนอน'] = df['ระยะเวลาการนอน'].replace({
# C:\Users\spire\AppData\Local\Temp\ipykernel_72868\2237283390.py:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['นิสิยการกินอาหาร'] = df['นิสิยการกินอาหาร'].replace({
# C:\Users\spire\AppData\Local\Temp\ipykernel_72868\2237283390.py:20: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['เคยคิดฆ่าตัวตาย'] = df['เคยคิดฆ่าตัวตาย'].replace({'Yes': 1, 'No': 0})
# C:\Users\spire\AppData\Local\Temp\ipykernel_72868\2237283390.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['เคยกินยานอนหลับ'] = df['เคยกินยานอนหลับ'].replace({'Yes': 1, 'No': 0})
# C:\Users\spire\AppData\Local\Temp\ipykernel_72868\2237283390.py:26: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['ภาวะซึมเศร้า'] = df['ภาวะซึมเศร้า'].replace({'Yes': 1, 'No': 0})
#    เพศ  อายุ เคยมีแฟนมาแล้ว  (คน) จำนวนครั้งที่ไปออกกำลังกายต่อสัปดาห์  \
# 0    1    28                    5                                    3
# 1    1    23                    5                                    2
# 2    0    23                    1                                    3
# 3    0    20                    5                                    5
# 4    1    29                    4                                    3
#
#    ระยะเวลาการนอน  นิสิยการกินอาหาร  เคยคิดฆ่าตัวตาย  \
# 0             5.5                 0                1
# 1             8.5                 1                0
# 2             4.5                 0                1
# 3             8.5                 2                1
# 4             8.5                 2                1
#
#   จำนวนชั่วโมงที่เข้าห้องสมุดในหนึ่งสัปดาห์ ระดับความเครียดด้านการเงิน  \
# 0                                         8                          3
# 1                                        10                          4
# 2                                         0                          3
# 3                                         2                          5
# 4                                         1                          3
#
#    เคยกินยานอนหลับ  ภาวะซึมเศร้า
# 0                1             1
# 1                0             1
# 2                0             0
# 3                0             1
# 4                0             1

# %% [markdown]
# ## Seperate Features and Targets

# %%
X = df.iloc[:, :-1]  # Features
y = df.iloc[:, -1] # Target

# %%
X.head()
# Out:
#    เพศ  อายุ เคยมีแฟนมาแล้ว  (คน) จำนวนครั้งที่ไปออกกำลังกายต่อสัปดาห์  \
# 0    1    28                    5                                    3
# 1    1    23                    5                                    2
# 2    0    23                    1                                    3
# 3    0    20                    5                                    5
# 4    1    29                    4                                    3
#
#    ระยะเวลาการนอน  นิสิยการกินอาหาร  เคยคิดฆ่าตัวตาย  \
# 0             5.5                 0                1
# 1             8.5                 1                0
# 2             4.5                 0                1
# 3             8.5                 2                1
# 4             8.5                 2                1
#
#   จำนวนชั่วโมงที่เข้าห้องสมุดในหนึ่งสัปดาห์ ระดับความเครียดด้านการเงิน  \
# 0                                         8                          3
# 1                                        10                          4
# 2                                         0                          3
# 3                                         2                          5
# 4                                         1                          3
#
#    เคยกินยานอนหลับ
# 0                1
# 1                0
# 2                0
# 3                0
# 4                0

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# Name: ภาวะซึมเศร้า, dtype: int64

# %% [markdown]
# ## Do Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# #### DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

DTreeClassifier = DecisionTreeClassifier(random_state=42)
DTreeClassifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
DTreeClassifier.score(X_test, y_test)
# Out:
# 0.7978723404255319

# %%
from sklearn.tree import export_graphviz
from graphviz import Source

#Save dot file
dot_data = export_graphviz(
    DTreeClassifier,
    out_file=None,
    feature_names=X.columns,
    filled=True,
    rounded=True,
    special_characters=True
)

with open("decision_tree.dot", "w", encoding="utf-8") as f:
    f.write(dot_data)

graph = Source(dot_data)
graph

# %% [markdown]
# #### DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

DTreeRegressor = DecisionTreeRegressor()
DTreeRegressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
DTreeRegressor.score(X_test, y_test)
# Out:
# 0.16736596736596743

# %%
from sklearn.tree import export_graphviz
from graphviz import Source

Source(export_graphviz(
    DTreeRegressor,
    out_file=None,
    feature_names=X.columns
))

# %% [markdown]
# ### Prediction

# %%
#args 
#เพศ / อายุ / amount of แฟน / amount of ออกกำลังกาย / ระยะเวลาการนอน / นิสัยการกินอาหาร / เคยคิดฆ่าตัวตาย / amount of ห้องสมุด / ระดับความเครียดการเงิน / เคยกินยานอนหลับ
#0 -> Female, 1 -> Male
#0 -> No, 1 -> Yes


DTreeClassifier.predict([[1,23,3,5,5.5,2,0,10,1,0], 
                         [0,19,1,2,8.5,1,1,3,5,0],
                         [1,20,1,0,4.5,3,1,0,10,1],
                         [0,25,1,0,4.0,3,1,1,8,1]])
# Out:
# c:\Users\spire\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0, 0, 1, 1])

# %% [markdown]
# ## Performance

# %%
DTreeClassifier.feature_importances_
# Out:
# array([0.00357588, 0.14238101, 0.25476632, 0.14105337, 0.0386228 ,
#        0.03256605, 0.19099132, 0.05791648, 0.12286167, 0.0152651 ])
